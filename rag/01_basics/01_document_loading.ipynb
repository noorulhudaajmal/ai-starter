# %%
import warnings

warnings.filterwarnings("ignore")

# %%
import pprint

from langchain_community.document_loaders import PyPDFLoader
# Out:
# 2026-02-26 04:02:35.601350: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# In retrieval augmented generation (RAG), an LLM retrieves contextual documents from an external dataset as part of its execution.
#
# This is useful if we want to ask question about specific documents (e.g., our PDFs, a set of videos, etc).

# %% [markdown]
# ## PDFs

# %%
loader = PyPDFLoader("./data/random_info.pdf")

# %%
pages = loader.load()

# %%
type(pages)
# Out:
# list

# %%
len(pages)
# Out:
# 2

# %%
pprint.pp(pages[0].schema())
# Out:
# {'description': 'Class for storing a piece of text and associated metadata.\n'
#                 '\n'
#                 '!!! note\n'
#                 '    `Document` is for **retrieval workflows**, not chat I/O. '
#                 'For sending text\n'
#                 '    to an LLM in a conversation, use message types from '
#                 '`langchain.messages`.\n'
#                 '\n'
#                 'Example:\n'
#                 '    ```python\n'
#                 '    from langchain_core.documents import Document\n'
#                 '\n'
#                 '    document = Document(\n'
#                 '        page_content="Hello, world!", metadata={"source": '
#                 '"https://example.com"}\n'
#                 '    )\n'
#                 '    ```',
#  'properties': {'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#                        'default': None,
#                        'title': 'Id'},
#                 'metadata': {'additionalProperties': True,
#                              'title': 'Metadata',
#                              'type': 'object'},
#                 'page_content': {'title': 'Page Content', 'type': 'string'},
#                 'type': {'const': 'Document',
#                          'default': 'Document',
#                          'title': 'Type',
#                          'type': 'string'}},
#  'required': ['page_content'],
#  'title': 'Document',
#  'type': 'object'}

# %%
pprint.pp(pages[0].metadata)
# Out:
# {'producer': 'ReportLab PDF Library - www.reportlab.com',
#  'creator': '(unspecified)',
#  'creationdate': '2026-02-25T22:58:55+00:00',
#  'author': '(anonymous)',
#  'keywords': '',
#  'moddate': '2026-02-25T22:58:55+00:00',
#  'subject': '(unspecified)',
#  'title': '(anonymous)',
#  'trapped': '/False',
#  'source': './data/random_info.pdf',
#  'total_pages': 2,
#  'page': 0,
#  'page_label': '1'}

# %%
print(pages[0].page_content)
# Out:
# Random Information – Page 1
# The world is full of fascinating facts and unexpected connections. For example, octopuses have
# three hearts and blue blood, which helps them survive in cold ocean environments. Meanwhile,
# honey never spoils—archaeologists have discovered jars of honey in ancient tombs that are still
# edible after thousands of years. Technology is evolving rapidly, shaping how humans interact with
# the world. Artificial intelligence systems are now capable of generating images, writing text, and
# even assisting in medical diagnoses. Renewable energy sources such as solar and wind are
# becoming more affordable, encouraging countries to transition toward cleaner power solutions.
# Nature also offers countless wonders. Forest ecosystems communicate through underground
# fungal networks sometimes called the “wood wide web,” allowing trees to share nutrients and
# chemical signals. Scientists continue to explore these networks to understand cooperation in
# nature.

# %% [markdown]
# Each page is a `Document`.
#
# A `Document` contains text (`page_content`) and `metadata`.

# %% [markdown]
# ## URLs

# %%
from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader = WebBaseLoader("https://github.com/basecamp/handbook/blob/master/titles-for-programmers.md")

# %%
docs = loader.load()

# %%
pprint.pp(docs[0].metadata)
# Out:
# {'source': 'https://github.com/basecamp/handbook/blob/master/titles-for-programmers.md',
#  'title': 'handbook/titles-for-programmers.md at master · basecamp/handbook · '
#           'GitHub',
#  'description': 'Basecamp Employee Handbook. Contribute to basecamp/handbook '
#                 'development by creating an account on GitHub.',
#  'language': 'en'}

# %%
print(docs[0].page_content[:500])
# Out:
# handbook/titles-for-programmers.md at master · basecamp/handbook · GitHub
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation Menu
#
# Toggle navigation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Sign in
#
#
#
#
#
#
# Appearance settings
#
#
#
#
#
#
#
#
#
#
#
# PlatformAI CODE CREATIONGitHub CopilotWrite better code with AIGitHub SparkBuild and deploy intelligent appsGitHub ModelsManage
